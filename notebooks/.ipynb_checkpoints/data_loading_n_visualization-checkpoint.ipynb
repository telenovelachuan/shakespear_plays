# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
processed_data = pd.read_csv("../data/processed/processed.csv")
print "A glance of the final processed dataset that adds explorative features"
processed_data.head()
# Out:
# A glance of the final processed dataset that adds explorative features
#    Dataline      Play  Play_length  PlayerLinenumber ActSceneLine  ASL_1  \
# 0         1  Henry IV            8               NaN          NaN    NaN
# 1         2  Henry IV            8               NaN          NaN    NaN
# 2         3  Henry IV            8               NaN          NaN    NaN
# 3         4  Henry IV            8               1.0        1.1.1    1.0
# 4         5  Henry IV            8               1.0        1.1.2    1.0
#
#    ASL_2  ASL_3         Player  PL_length  PL_w_count  PL_w_density  \
# 0    NaN    NaN            NaN          5           2      2.500000
# 1    NaN    NaN            NaN         28           5      5.600000
# 2    NaN    NaN            NaN         96          16      6.000000
# 3    1.0    1.0  KING HENRY IV         38           9      4.222222
# 4    1.0    2.0  KING HENRY IV         42           9      4.666667
#
#                                           PlayerLine  PL_contain_!  \
# 0                                              ACT I         False
# 1                       SCENE I. London. The palace.         False
# 2  Enter KING HENRY, LORD JOHN OF LANCASTER, the ...         False
# 3             So shaken as we are, so wan with care,         False
# 4         Find we a time for frighted peace to pant,         False
#
#    PL_contain_?  PL_#_comma_split  PL_#_stop_words  PL_#_upper_case
# 0         False                 1                1                4
# 1         False                 1                1                8
# 2         False                 5                4               59
# 3         False                 3                5                1
# 4         False                 2                4                1

# %%
'''
Number of PlayerLines grouped by column Player
'''
play_data = processed_data.groupby('Player').count().sort_values(by='PlayerLine', ascending=False)['PlayerLine']
play_data = play_data.to_frame()
play_data['Player'] = play_data.index.tolist()
play_data.index = np.arange(0, len(play_data))
play_data = play_data[:MAX_ITEM_NUM]
play_data.columns = ['Lines', 'Player']

plt.figure(figsize=(15, 7))
ax = sns.barplot(x='Lines', y='Player', data=play_data, order=play_data['Player'])
ax.set(xlabel='Number of PlayerLine', ylabel='Player')
ax.yaxis.set_label_coords(-0.05, 1.02)
plt.ylabel('Player', rotation=0)
plt.show()

# %%
print "Frequency distribution of PlayerLine_length"
ax1 = processed_data['PL_length'].value_counts().sort_index()[:100].plot(kind='area')
ax1.set(xlabel='PlayerLine length', ylabel='Frequency')
plt.show()
# Out:
# Frequency distribution of PlayerLine_length

# %%
print "Frequency distribution of PlayerLine word count"
ax1 = processed_data['PL_w_count'].value_counts().sort_index()[:50].plot(kind='area')
ax1.set(xlabel='PlayerLine word count', ylabel='Frequency')
ax1.set_xlim(0, 30)
plt.show()
# Out:
# Frequency distribution of PlayerLine word count

# %%
print "Pearson correlation matrix of all features"
colormap = plt.cm.RdBu
plt.figure(figsize=(14, 7))
plt.title('Pearson Correlation of Features', y=1.05, size=15)
sns.heatmap(processed_data.apply(lambda x : pd.factorize(x)[0]).corr(method='pearson', min_periods=1).round(decimals=2),
            linewidths=0.1, vmax=1.0, square=True, cmap=colormap, linecolor='white', annot=True)
plt.xticks(rotation=45, fontsize=7)

plt.show()
# Out:
# Pearson correlation matrix of all features
